# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, polynomial_kernel, rbf_kernel
import math, re

# %%
df_grain = pd.read_csv("grain_machinery_data.csv")
df_grain.head()
# Out:
#    Grain                 Machine Name          Manufacturer  \
# 0  Wheat  Wheat Flour Milling Machine          Buhler Group
# 1   Rice          Rice Huller Machine    Satake Corporation
# 2   Oats          Oat Flaking Machine  CPM Roskamp Champion
# 3   Corn         Corn Milling Machine          Alvan Blanch
# 4  Wheat              Wheat De-stoner          Alvan Blanch
#
#    Capacity (tons/hour)  Power Output (kW) Dimensions (LxWxH in meters)  \
# 0                   100                200                       10x3x4
# 1                     4                 10                        5x2x3
# 2                    10                 25                        8x2x3
# 3                    20                 50                       12x3x4
# 4                    50                100                        6x2x3
#
#    Price (USD)  Price (INR)
# 0      1200000     99600000
# 1        30000      2490000
# 2        80000      6640000
# 3       150000     12450000
# 4        15000      1245000

# %%
df_filtered = df_grain[df_grain['Grain'] == 'Corn']
df_filtered
# Out:
#    Grain              Machine Name         Manufacturer  Capacity (tons/hour)  \
# 3   Corn      Corn Milling Machine         Alvan Blanch                    20
# 7   Corn                Corn Dryer  Sukup Manufacturing                    10
# 11  Corn      Corn Peeling Machine    Huantai Machinery                    25
# 15  Corn        Corn Grits Machine   Satake Corporation                    18
# 19  Corn        Corn Steeping Tank         Alvan Blanch                    22
# 23  Corn              Corn Grinder         Buhler Group                    19
# 27  Corn         Corn Degerminator   Satake Corporation                    21
# 31  Corn      Corn Puffing Machine         Buhler Group                    23
# 35  Corn        Corn Flour Machine   Satake Corporation                    20
# 39  Corn              Corn Sheller         Buhler Group                    27
# 43  Corn         Corn Cooking Tank         Alvan Blanch                    24
# 47  Corn      Corn Flaking Machine         Buhler Group                    30
# 51  Corn  Corn Wet Milling Machine   Satake Corporation                    26
# 55  Corn             Corn Extruder         Buhler Group                    28
# 59  Corn       Corn Bran Separator   Satake Corporation                    29
#
#     Power Output (kW) Dimensions (LxWxH in meters)  Price (USD)  Price (INR)
# 3                  50                       12x3x4       150000     12450000
# 7                  30                     10x2.5x3        55000      4565000
# 11                 60                       13x3x4        60000      4980000
# 15                 70                     14x3.5x4       110000      9130000
# 19                 65                     15x3.5x4       130000     10790000
# 23                 75                       13x3x4       140000     11620000
# 27                 85                     14x3.5x4       145000     12035000
# 31                 80                     15x3.5x4       150000     12450000
# 35                100                       16x4x5       170000     14110000
# 39                 95                       13x3x4       190000     15770000
# 43                110                     15x3.5x4       135000     11205000
# 47                125                       16x4x5       155000     12865000
# 51                105                       17x4x5       165000     13695000
# 55                130                       17x4x5       175000     14525000
# 59                150                   18x4.5x5.5       185000     15355000

# %%
df_grain.fillna({
    'Capacity (tons/hour)': 0,
    'Power Output (kW)': 0,
    'Price (INR)': 0,
    'Machine Name': '',
}, inplace=True)
tfidf = TfidfVectorizer(stop_words="english")
tfidf_matrix = tfidf.fit_transform(df_grain["Machine Name"])

# %%
print(tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 159 stored elements and shape (60, 55)>
#   Coords	Values
#   (0, 52)	0.4187718215799111
#   (0, 14)	0.6270846465041181
#   (0, 28)	0.5668246341925239
#   (0, 27)	0.33182049611493225
#   (1, 27)	0.34756547774806307
#   (1, 35)	0.43864266957287124
#   (1, 22)	0.8287284519719023
#   (2, 27)	0.3705658102710222
#   (2, 29)	0.46767008427556966
#   (2, 13)	0.8024747176901353
#   (3, 28)	0.7276767697147049
#   (3, 27)	0.4259837208416609
#   (3, 6)	0.5376098849495481
#   (4, 52)	0.4678078135222817
#   (4, 47)	0.8838302153736893
#   (5, 27)	0.3705658102710222
#   (5, 35)	0.46767008427556966
#   (5, 33)	0.8024747176901353
#   (6, 27)	0.34756547774806307
#   (6, 29)	0.43864266957287124
#   (6, 23)	0.8287284519719023
#   (7, 6)	0.5035173947097267
#   (7, 10)	0.8639850885430428
#   (8, 52)	0.4361367906660645
#   (8, 1)	0.6530876031019691
#   :	:
#   (51, 6)	0.37717384274852844
#   (51, 51)	0.7125952774490718
#   (52, 52)	0.46767008427556966
#   (52, 27)	0.3705658102710222
#   (52, 33)	0.8024747176901353
#   (53, 35)	0.4678078135222817
#   (53, 49)	0.8838302153736893
#   (54, 29)	0.38100781564683955
#   (54, 20)	0.6537710013513999
#   (54, 7)	0.6537710013513999
#   (55, 6)	0.4678078135222817
#   (55, 11)	0.8838302153736893
#   (56, 52)	0.43864266957287124
#   (56, 27)	0.34756547774806307
#   (56, 41)	0.8287284519719023
#   (57, 35)	0.3897119883321735
#   (57, 39)	0.5531826068425769
#   (57, 21)	0.7362836203780679
#   (58, 28)	0.5668246341925239
#   (58, 27)	0.33182049611493225
#   (58, 29)	0.4187718215799111
#   (58, 1)	0.6270846465041181
#   (59, 6)	0.4361367906660645
#   (59, 1)	0.6530876031019691
#   (59, 39)	0.6190809983370759

# %%
# cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
cosine_sim = polynomial_kernel(tfidf_matrix, tfidf_matrix)
# cosine_sim = rbf_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(df_grain.index, index=df_grain['Machine Name']).drop_duplicates()
indices
# Out:
# Machine Name
# Wheat Flour Milling Machine     0
# Rice Huller Machine             1
# Oat Flaking Machine             2
# Corn Milling Machine            3
# Wheat De-stoner                 4
# Rice Polishing Machine          5
# Oat De-hulling Machine          6
# Corn Dryer                      7
# Wheat Bran Separator            8
# Rice Grading Machine            9
# Oat Groat Cutter               10
# Corn Peeling Machine           11
# Wheat Cleaning Machine         12
# Rice Whitener                  13
# Oat Rolling Machine            14
# Corn Grits Machine             15
# Wheat Blending Machine         16
# Rice Husker                    17
# Oat Steam Conditioner          18
# Corn Steeping Tank             19
# Wheat Grader                   20
# Rice Sifter                    21
# Oat Sheller                    22
# Corn Grinder                   23
# Wheat Separator                24
# Rice Dryer                     25
# Oat Mill                       26
# Corn Degerminator              27
# Wheat Washer                   28
# Rice Destoner                  29
# Oat Flour Mill                 30
# Corn Puffing Machine           31
# Wheat Scourer                  32
# Rice Whitening Machine         33
# Oat Bran Finisher              34
# Corn Flour Machine             35
# Wheat Peeler                   36
# Rice Silky Polisher            37
# Oat Grain Polisher             38
# Corn Sheller                   39
# Wheat Impactor                 40
# Rice Separator                 41
# Oat Roller Mill                42
# Corn Cooking Tank              43
# Wheat Conditioning Machine     44
# Rice Milling Machine           45
# Oat Husking Machine            46
# Corn Flaking Machine           47
# Wheat Whitening Machine        48
# Rice Sorter                    49
# Oat Flour Milling Machine      50
# Corn Wet Milling Machine       51
# Wheat Polishing Machine        52
# Rice Thresher                  53
# Oat Groat Cutter               54
# Corn Extruder                  55
# Wheat Sieving Machine          56
# Rice Hull Separator            57
# Oat Bran Milling Machine       58
# Corn Bran Separator            59
# dtype: int64

# %%
indices['Rice Huller Machine']
# Out:
# np.int64(1)

# %%
def get_recommendation_1(machine_name, cosine_sim = cosine_sim, n=5):
    l1 = []
    possible_matches = [name for name in df_grain['Machine Name'] if re.search(machine_name, name, re.IGNORECASE)]
    machine_name = possible_matches[0]
    idx = indices[machine_name]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x:x[1], reverse=True)#[1:n+1]
    for i, score in sim_scores:
        # print(df_grain['Machine Name'].iloc[i])
        l1.append(i)
    return l1
    
grain = "Rice"
l2 = get_recommendation_1(grain, cosine_sim, 20)
print(l2)
# Out:
# [1, 45, 5, 33, 9, 41, 25, 13, 17, 21, 29, 49, 53, 57, 37, 3, 35, 2, 47, 48, 52, 6, 11, 12, 14, 15, 16, 31, 44, 46, 56, 0, 50, 58, 51, 4, 7, 8, 10, 18, 19, 20, 22, 23, 24, 26, 27, 28, 30, 32, 34, 36, 38, 39, 40, 42, 43, 54, 55, 59]

# %%
def to_dataframe(list1, df):
    return df.loc[list1]

# %%
new_df = to_dataframe(l2, df_grain)
new_df = new_df[new_df['Grain'] == grain]
new_df[1:21]
# new_df
# Out:
#    Grain            Machine Name        Manufacturer  Capacity (tons/hour)  \
# 45  Rice    Rice Milling Machine   Huantai Machinery                    12
# 5   Rice  Rice Polishing Machine  Satake Corporation                     5
# 33  Rice  Rice Whitening Machine  Satake Corporation                     2
# 9   Rice    Rice Grading Machine        Alvan Blanch                     3
# 41  Rice          Rice Separator  Satake Corporation                     4
# 25  Rice              Rice Dryer   Huantai Machinery                     9
# 13  Rice           Rice Whitener        Buhler Group                     7
# 17  Rice             Rice Husker        Buhler Group                     6
# 21  Rice             Rice Sifter  Satake Corporation                     8
# 29  Rice           Rice Destoner        Buhler Group                     5
# 49  Rice             Rice Sorter        Buhler Group                     8
# 53  Rice           Rice Thresher  Satake Corporation                    10
# 57  Rice     Rice Hull Separator   Huantai Machinery                    11
# 37  Rice     Rice Silky Polisher   Huantai Machinery                     7
#
#     Power Output (kW) Dimensions (LxWxH in meters)  Price (USD)  Price (INR)
# 45                 25                        5x2x3        50000      4150000
# 5                  15                    4x1.5x2.5        25000      2075000
# 33                  8                    4x1.5x2.5        22000      1826000
# 9                   5                    4x1.5x2.5        20000      1660000
# 41                 15                    4x1.5x2.5        35000      2905000
# 25                 20                        5x2x3        60000      4980000
# 13                 12                        5x2x3        50000      4150000
# 17                 25                        5x2x3        35000      2905000
# 21                 15                        6x2x3        40000      3320000
# 29                 25                        5x2x3        50000      4150000
# 49                 30                        5x2x3        55000      4565000
# 53                 35                        6x2x3        45000      3735000
# 57                 35                        6x2x3        70000      5810000
# 37                 20                        6x2x3        70000      5810000

# %%
def get_recommendation_2(df):                             # normalization + score_calculation + get recommendation
    df['Price (INR)'] = df['Price (INR)'] / math.pow(10, 6)
    df['Score'] = 0.3 * df['Capacity (tons/hour)'] + 0.5 * df['Power Output (kW)'] + 0.2 * df['Price (INR)']
    min_score = df['Score'].min()
    max_score = df['Score'].max()

    df['Score'] = (4 * (df['Score'] - min_score) / (max_score - min_score) + 1).round().astype(int) 
    sorted_df = df.sort_values(by = 'Score', ascending = False)

    return sorted_df

# %%
new_df = get_recommendation_2(new_df)
new_df
# Out:
#    Grain            Machine Name        Manufacturer  Capacity (tons/hour)  \
# 57  Rice     Rice Hull Separator   Huantai Machinery                    11
# 53  Rice           Rice Thresher  Satake Corporation                    10
# 45  Rice    Rice Milling Machine   Huantai Machinery                    12
# 49  Rice             Rice Sorter        Buhler Group                     8
# 17  Rice             Rice Husker        Buhler Group                     6
# 25  Rice              Rice Dryer   Huantai Machinery                     9
# 29  Rice           Rice Destoner        Buhler Group                     5
# 37  Rice     Rice Silky Polisher   Huantai Machinery                     7
# 1   Rice     Rice Huller Machine  Satake Corporation                     4
# 41  Rice          Rice Separator  Satake Corporation                     4
# 5   Rice  Rice Polishing Machine  Satake Corporation                     5
# 21  Rice             Rice Sifter  Satake Corporation                     8
# 13  Rice           Rice Whitener        Buhler Group                     7
# 33  Rice  Rice Whitening Machine  Satake Corporation                     2
# 9   Rice    Rice Grading Machine        Alvan Blanch                     3
#
#     Power Output (kW) Dimensions (LxWxH in meters)  Price (USD)  Price (INR)  \
# 57                 35                        6x2x3        70000        5.810
# 53                 35                        6x2x3        45000        3.735
# 45                 25                        5x2x3        50000        4.150
# 49                 30                        5x2x3        55000        4.565
# 17                 25                        5x2x3        35000        2.905
# 25                 20                        5x2x3        60000        4.980
# 29                 25                        5x2x3        50000        4.150
# 37                 20                        6x2x3        70000        5.810
# 1                  10                        5x2x3        30000        2.490
# 41                 15                    4x1.5x2.5        35000        2.905
# 5                  15                    4x1.5x2.5        25000        2.075
# 21                 15                        6x2x3        40000        3.320
# 13                 12                        5x2x3        50000        4.150
# 33                  8                    4x1.5x2.5        22000        1.826
# 9                   5                    4x1.5x2.5        20000        1.660
#
#     Score
# 57      5
# 53      5
# 45      4
# 49      4
# 17      3
# 25      3
# 29      3
# 37      3
# 1       2
# 41      2
# 5       2
# 21      2
# 13      2
# 33      1
# 9       1
